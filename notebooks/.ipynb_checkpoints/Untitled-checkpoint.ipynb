# %%
import math
import json
import numpy as np
import pandas as pd
import networkx as nx
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline

# %%
names = ('airline,airline_id,'
         'source,source_id,'
         'dest,dest_id,'
         'codeshare,stops,equipment').split(',')
routes = pd.read_csv(
    'routes.csv',
    names=names,
    header=None,
    skiprows=[0])
routes
# Out:
#       airline airline_id source source_id dest dest_id codeshare  stops  \
# 0          2B        410    AER      2965  KZN    2990       NaN      0
# 1          2B        410    ASF      2966  KZN    2990       NaN      0
# 2          2B        410    ASF      2966  MRV    2962       NaN      0
# 3          2B        410    CEK      2968  KZN    2990       NaN      0
# 4          2B        410    CEK      2968  OVB    4078       NaN      0
# ...       ...        ...    ...       ...  ...     ...       ...    ...
# 67658      ZL       4178    WYA      6334  ADL    3341       NaN      0
# 67659      ZM      19016    DME      4029  FRU    2912       NaN      0
# 67660      ZM      19016    FRU      2912  DME    4029       NaN      0
# 67661      ZM      19016    FRU      2912  OSS    2913       NaN      0
# 67662      ZM      19016    OSS      2913  FRU    2912       NaN      0
#
#       equipment
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           CR2
# ...         ...
# 67658       SF3
# 67659       734
# 67660       734
# 67661       734
# 67662       734
#
# [67663 rows x 9 columns]

# %%
names = ('id,name,city,country,iata,icao,lat,lon,'
         'alt,timezone,dst,tz,type,source').split(',')
airports = pd.read_csv(
    'airport.csv',
    header=None,
    names=names,
    index_col=4,
    na_values='\\N')
airports_us = airports[airports['country'] ==
                       'United States']
airports_us
# Out:
#          id                                      name             city  \
# iata
# BTI    3411                Barter Island LRRS Airport    Barter Island
# NaN    3412                    Wainwright Air Station  Fort Wainwright
# LUR    3413                Cape Lisburne LRRS Airport    Cape Lisburne
# PIZ    3414                    Point Lay LRRS Airport        Point Lay
# ITO    3415                Hilo International Airport             Hilo
# ...     ...                                       ...              ...
# NaN   13717  Camp Pendleton MCAS (Munn Field) Airport        Oceanside
# VDI   13757                  Vidalia Regional Airport          Vidalia
# NaN   13758                 Granbury Regional Airport         Granbury
# NaN   13759                     Oswego County Airport           Fulton
# MHE   13803                Mitchell Municipal Airport         Mitchell
#
#             country  icao                 lat                  lon   alt  \
# iata
# BTI   United States  PABA   70.13400268550001       -143.582000732     2
# NaN   United States  PAWT         70.61340332         -159.8600006    35
# LUR   United States  PALU         68.87509918         -166.1100006    16
# PIZ   United States  PPIZ         69.73290253  -163.00500490000002    22
# ITO   United States  PHTO  19.721399307250977  -155.04800415039062    38
# ...             ...   ...                 ...                  ...   ...
# NaN   United States  KNFG         33.30130005         -117.3550034    78
# VDI   United States  KVDI     32.192699432373     -82.371200561523   275
# NaN   United States  KGDJ         32.44440079         -97.81690216   778
# NaN   United States  KFZY   43.35079956054688   -76.38809967041016   475
# MHE   United States  KMHE       43.7747993469       -98.0385971069  1304
#
#      timezone  dst                 tz     type       source
# iata
# BTI        -9    A  America/Anchorage  airport  OurAirports
# NaN        -9    A  America/Anchorage  airport  OurAirports
# LUR        -9    A  America/Anchorage  airport  OurAirports
# PIZ        -9    A  America/Anchorage  airport  OurAirports
# ITO       -10    N   Pacific/Honolulu  airport  OurAirports
# ...       ...  ...                ...      ...          ...
# NaN       NaN  NaN                NaN  airport  OurAirports
# VDI        -4    A                NaN  airport  OurAirports
# NaN        -5    A                NaN  airport  OurAirports
# NaN        -4    A                NaN  airport  OurAirports
# MHE        -6    A                NaN  airport  OurAirports
#
# [1512 rows x 13 columns]

# %%
routes_us = routes[
    routes['source'].isin(airports_us.index) &
    routes['dest'].isin(airports_us.index)]
routes_us
# Out:
#       airline airline_id source source_id dest dest_id codeshare  stops  \
# 172        2O        146    ADQ      3531  KLN    7162       NaN      0
# 177        2O        146    KLN      7162  KYK    7161       NaN      0
# 260        3E      10739    BRL      5726  ORD    3830       NaN      0
# 261        3E      10739    BRL      5726  STL    3678       NaN      0
# 262        3E      10739    DEC      4042  ORD    3830       NaN      0
# ...       ...        ...    ...       ...  ...     ...       ...    ...
# 67565      ZK       2607    SHR      5769  DEN    3751       NaN      0
# 67566      ZK       2607    SOW      7078  FMN    3743       NaN      0
# 67567      ZK       2607    SOW      7078  PHX    3462       NaN      0
# 67569      ZK       2607    VIS      7121  LAX    3484       NaN      0
# 67570      ZK       2607    WRL      5777  CYS    3804       NaN      0
#
#       equipment
# 172         BNI
# 177         BNI
# 260         CNC
# 261         CNC
# 262         CNC
# ...         ...
# 67565       EM2
# 67566       BE1
# 67567       BE1
# 67569       BE1
# 67570   BEH BE1
#
# [10518 rows x 9 columns]

# %%
edges = routes_us[['source', 'dest']].values
edges
# Out:
# array([['ADQ', 'KLN'],
#        ['KLN', 'KYK'],
#        ['BRL', 'ORD'],
#        ...,
#        ['SOW', 'PHX'],
#        ['VIS', 'LAX'],
#        ['WRL', 'CYS']], dtype=object)

# %%
g = nx.from_edgelist(edges)

# %%
len(g.nodes()), len(g.edges())
# Out:
# (549, 2787)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
nx.draw_networkx(g, ax=ax, node_size=5,
                 font_size=6, alpha=.5,
                 width=.5)
ax.set_axis_off()

# %%
sg = (g.subgraph(c) for c in nx.connected_components(g))
sg = list(sg)[0]

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
nx.draw_networkx(sg, ax=ax, with_labels=False,
                 node_size=5, width=.5)
ax.set_axis_off()

# %%
airports_us.reset_index(inplace=True)

pos = {airport: (v['lon'], v['lat'])
       for airport, v in
       airports_us.to_dict('index').items()}

# %%
def connected_component_subgraphs(g):
    for c in nx.connected_components(g):
        yield g.subgraph(c)

# %%
sg = next(connected_component_subgraphs(g))

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
nx.draw_networkx(sg, ax=ax, with_labels=False,
                 node_size=5, width=.5)
ax.set_axis_off()

# %%
pos = {airport: (v['lon'], v['lat'])
       for airport, v in
       airports_us.to_dict('index').items()}

# %%
deg = nx.degree(sg)
sizes = [5 * deg[iata] for iata in sg.nodes]

# %%
altitude = airports_us['alt']
altitude = [altitude[iata] for iata in sg.nodes]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-6eccff6534e2> in <module>
#       1 altitude = airports_us['alt']
# ----> 2 altitude = [altitude[iata] for iata in sg.nodes]
#
# <ipython-input-60-6eccff6534e2> in <listcomp>(.0)
#       1 altitude = airports_us['alt']
# ----> 2 altitude = [altitude[iata] for iata in sg.nodes]
#
# ~\anaconda3\envs\gradient\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\anaconda3\envs\gradient\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~\anaconda3\envs\gradient\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: 'ADQ'

# %%
labels = {iata: iata if deg[iata] >= 20 else ''
          for iata in sg.nodes}

# %%
# Map projection
crs = ccrs.PlateCarree()
fig, ax = plt.subplots(
    1, 1, figsize=(12, 8),
    subplot_kw=dict(projection=crs))
ax.coastlines()
# Extent of continental US.
ax.set_extent([-128, -62, 20, 50])
nx.draw_networkx(sg, ax=ax,
                 font_size=16,
                 alpha=.5,
                 width=.075,
                 node_size=sizes,
                 labels=labels,
                 pos=pos,
                 cmap=plt.cm.autumn)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\gradient\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label)
#     455     try:
# --> 456         xy = np.asarray([pos[v] for v in nodelist])
#     457     except KeyError as e:
#
# ~\anaconda3\envs\gradient\lib\site-packages\networkx\drawing\nx_pylab.py in <listcomp>(.0)
#     455     try:
# --> 456         xy = np.asarray([pos[v] for v in nodelist])
#     457     except KeyError as e:
#
# KeyError: 'ADQ'
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-63-3906005df15f> in <module>
#      14                  labels=labels,
#      15                  pos=pos,
# ---> 16                  cmap=plt.cm.autumn)
#
# ~\anaconda3\envs\gradient\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     333         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     334
# --> 335     draw_networkx_nodes(G, pos, **node_kwds)
#     336     draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     337     if with_labels:
#
# ~\anaconda3\envs\gradient\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label)
#     456         xy = np.asarray([pos[v] for v in nodelist])
#     457     except KeyError as e:
# --> 458         raise nx.NetworkXError(f"Node {e} has no position.") from e
#     459     except ValueError as e:
#     460         raise nx.NetworkXError("Bad value in node positions.") from e
#
# NetworkXError: Node 'ADQ' has no position.
